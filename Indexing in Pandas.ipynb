# %%
import pandas as pd
data = pd.read_csv("./nba-2.csv", index_col=0)

# %%
data.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
data.columns
# Out:
# Index(['Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College',
#        'Salary'],
#       dtype='object')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
first = data['Age']

# %%
first
# Out:
# Name
# Avery Bradley              25.0
# Jae Crowder                25.0
# John Holland               27.0
# R.J. Hunter                22.0
# Jonas Jerebko              29.0
# Amir Johnson               29.0
# Jordan Mickey              21.0
# Kelly Olynyk               25.0
# Terry Rozier               22.0
# Marcus Smart               22.0
# Jared Sullinger            24.0
# Isaiah Thomas              27.0
# Evan Turner                27.0
# James Young                20.0
# Tyler Zeller               26.0
# Bojan Bogdanovic           27.0
# Markel Brown               24.0
# Wayne Ellington            28.0
# Rondae Hollis-Jefferson    21.0
# Jarrett Jack               32.0
# Sergey Karasev             22.0
# Sean Kilpatrick            26.0
# Shane Larkin               23.0
# Brook Lopez                28.0
# Chris McCullough           21.0
# Willie Reed                26.0
# Thomas Robinson            25.0
# Henry Sims                 26.0
# Donald Sloan               28.0
# ...

# %%
multi_select_cols_only = data[['Team','Number','Age']]

# %%
multi_select_cols_only
# Out:
#                                            Team  Number   Age
# Name
# Avery Bradley                    Boston Celtics     0.0  25.0
# Jae Crowder                      Boston Celtics    99.0  25.0
# John Holland                     Boston Celtics    30.0  27.0
# R.J. Hunter                      Boston Celtics    28.0  22.0
# Jonas Jerebko                    Boston Celtics     8.0  29.0
# Amir Johnson                     Boston Celtics    90.0  29.0
# Jordan Mickey                    Boston Celtics    55.0  21.0
# Kelly Olynyk                     Boston Celtics    41.0  25.0
# Terry Rozier                     Boston Celtics    12.0  22.0
# Marcus Smart                     Boston Celtics    36.0  22.0
# Jared Sullinger                  Boston Celtics     7.0  24.0
# Isaiah Thomas                    Boston Celtics     4.0  27.0
# Evan Turner                      Boston Celtics    11.0  27.0
# James Young                      Boston Celtics    13.0  20.0
# ...

# %% [markdown]
# Selecting Data using .loc indexer, which uses Label strings

# %% [markdown]
# Select the Details of Player Avery Bradley

# %%
avery_bradley_details = data.loc['Avery Bradley']

# %%
avery_bradley_details.Age
# Out:
# 25.0

# %% [markdown]
# Select the Details of Player R.J. Hunter

# %%
r_j_hunter_details = data.loc['R.J. Hunter']

# %%
r_j_hunter_details
# Out:
# Team        Boston Celtics
# Number                  28
# Position                SG
# Age                     22
# Height                 6-5
# Weight                 185
# College      Georgia State
# Salary         1.14864e+06
# Name: R.J. Hunter, dtype: object

# %%
type(r_j_hunter_details)
# Out:
# pandas.core.series.Series

# %%
data.head()
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0

# %%
multi_select_row_cols = data.loc[["Avery Bradley", "R.J. Hunter"], 
                   ["Team", "Number", "Position"]]

# %%
multi_select_row_cols
# Out:
#                          Team  Number Position
# Name
# Avery Bradley  Boston Celtics     0.0       PG
# R.J. Hunter    Boston Celtics    28.0       SG

# %%
all_rows_some_cols = data.loc[:, ["Team", "Number", "Position"]]

# %%
all_rows_some_cols
# Out:
#                                            Team  Number Position
# Name
# Avery Bradley                    Boston Celtics     0.0       PG
# Jae Crowder                      Boston Celtics    99.0       SF
# John Holland                     Boston Celtics    30.0       SG
# R.J. Hunter                      Boston Celtics    28.0       SG
# Jonas Jerebko                    Boston Celtics     8.0       PF
# Amir Johnson                     Boston Celtics    90.0       PF
# Jordan Mickey                    Boston Celtics    55.0       PF
# Kelly Olynyk                     Boston Celtics    41.0        C
# Terry Rozier                     Boston Celtics    12.0       PG
# Marcus Smart                     Boston Celtics    36.0       PG
# Jared Sullinger                  Boston Celtics     7.0        C
# Isaiah Thomas                    Boston Celtics     4.0       PG
# Evan Turner                      Boston Celtics    11.0       SG
# ...

# %% [markdown]
# Selecting Rows and columns using the iloc indexer

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data.iloc[0])
# Out:
# pandas.core.series.Series

# %%
type(data.Team)
# Out:
# pandas.core.series.Series

# %%
type(data.Team.iloc)
# Out:
# pandas.core.indexing._iLocIndexer

# %%
type(data.Team.iloc[0])
# Out:
# str

# %%
data.Team.iloc[100]
# Out:
# 'Los Angeles Clippers'

# %%
data.iloc[0]
# Out:
# Team        Boston Celtics
# Number                   0
# Position                PG
# Age                     25
# Height                 6-2
# Weight                 180
# College              Texas
# Salary         7.73034e+06
# Name: Avery Bradley, dtype: object

# %%
i_loc_indexer_data_for_row_3 = data.iloc[0]

# %%
i_loc_indexer_data_for_row_3
# Out:
# Team        Boston Celtics
# Number                   0
# Position                PG
# Age                     25
# Height                 6-2
# Weight                 180
# College              Texas
# Salary         7.73034e+06
# Name: Avery Bradley, dtype: object

# %%
type(i_loc_indexer_data_for_row_3)
# Out:
# pandas.core.series.Series

# %%
iloc_indexer_for_odd_rows = data.iloc[[3,5,7]]

# %%
iloc_indexer_for_odd_rows
# Out:
#                         Team  Number Position   Age Height  Weight  \
# Name
# R.J. Hunter   Boston Celtics    28.0       SG  22.0    6-5   185.0
# Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#                     College      Salary
# Name
# R.J. Hunter   Georgia State   1148640.0
# Amir Johnson            NaN  12000000.0
# Kelly Olynyk        Gonzaga   2165160.0

# %%
type(iloc_indexer_for_odd_rows)
# Out:
# pandas.core.frame.DataFrame

# %%
row2 = data.iloc [[3, 4], [1, 2]]

# %%
row2
# Out:
#                Number Position
# Name
# R.J. Hunter      28.0       SG
# Jonas Jerebko     8.0       PF

# %%
row3 = data.iloc [:, [1, 2]]

# %%
row3
# Out:
#                          Number Position
# Name
# Avery Bradley               0.0       PG
# Jae Crowder                99.0       SF
# John Holland               30.0       SG
# R.J. Hunter                28.0       SG
# Jonas Jerebko               8.0       PF
# Amir Johnson               90.0       PF
# Jordan Mickey              55.0       PF
# Kelly Olynyk               41.0        C
# Terry Rozier               12.0       PG
# Marcus Smart               36.0       PG
# Jared Sullinger             7.0        C
# Isaiah Thomas               4.0       PG
# Evan Turner                11.0       SG
# James Young                13.0       SG
# Tyler Zeller               44.0        C
# Bojan Bogdanovic           44.0       SG
# Markel Brown               22.0       SG
# Wayne Ellington            21.0       SG
# Rondae Hollis-Jefferson    24.0       SG
# Jarrett Jack                2.0       PG
# Sergey Karasev             10.0       SG
# Sean Kilpatrick             6.0       SG
# ...

# %% [markdown]
# Indexing a using Dataframe.ix[ ]
